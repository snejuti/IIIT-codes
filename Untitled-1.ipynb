# %%
import os

print(os.getcwd())#to check the current working directory
# Out:
# c:\Users\sneju\lexiguard-mern

# %%
import os

print(os.path.exists("file.csv/students_1000.csv"))#to check if the file exists in the current working directory
# Out:
# False
