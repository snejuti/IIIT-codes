# %%
import matplotlib.pyplot as plt#to import the matplotlib library for plotting
import pandas as pd #to import the pandas library for data manipulation
import numpy as np#to import the numpy library for numerical operations and array handling

# %%
df = pd.read_csv("file.csv/Employees_1000.csv")
print(df.head())
# Out:
#   Employee_ID Employee_Name               Designation  Salary
# 0     EMP0001    Employee_1  Senior Software Engineer   83278
# 1     EMP0002    Employee_2           Project Manager  122098
# 2     EMP0003    Employee_3            Data Scientist   88289
# 3     EMP0004    Employee_4  Senior Software Engineer  168696
# 4     EMP0005    Employee_5           DevOps Engineer   81395

# %%
import matplotlib.pyplot as plt

print("Matplotlib installed successfully!")
# Out:
# Matplotlib installed successfully!

# %%
xpoints=np.array([0,6])#points to be plotted on the x-axis
ypoints=np.array([0,250])#points to be plotted on the y-axis
plt.plot(xpoints, ypoints)#to create a line plot with the specified x and y points
plt.show()#to display the plot

# %%
import matplotlib.pyplot as plt#to import the matplotlib library for plotting
import pandas as pd #to import the pandas library for data manipulation
import numpy as np#to import the numpy library for numerical operations and array handling
xpoints=np.array([0,6])#points to be plotted on the x-axis
ypoints=np.array([0,250])#points to be plotted on the y-axis
plt.grid()#to add a grid to the plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt#to import the matplotlib library for plotting
import pandas as pd #to import the pandas library for data manipulation
import numpy as np#to import the numpy library for numerical operations and array handling
xpoints=np.array([0,6])#points to be plotted on the x-axis
ypoints=np.array([0,250])#points to be plotted on the y-axis
plt.scatter(xpoints, ypoints)#to create a scatter plot with the specified x and y points
plt.show()#to display the plot

# %%
plt.bar(xpoints, ypoints)#to create a bar chart with the specified x and y points
# Out:
# <BarContainer object of 2 artists>

# %%
plt.hist(xpoints, ypoints)#to create a histogram with the specified x and y points
# Out:
# (array([2.]), array([  0., 250.]), <BarContainer object of 1 artists>)

# %%
plt.pie(xpoints)#to create a pie chart with the specified x and y points
# Out:
# ([<matplotlib.patches.Wedge at 0x222491a3390>,
# ...
#  [Text(1.1, 0.0, ''), Text(-1.0999999999999959, -9.616505800409723e-08, '')])

# %%
import matplotlib.pyplot as plt#to import the matplotlib library for plotting
import pandas as pd #to import the pandas library for data manipulation
import numpy as np#to import the numpy library for numerical operations and array handling
df = pd.read_csv("../file.csv/Employees_1000.csv")#.. is used to navigate to the parent directory and then access the file.csv directory to read the Employees_1000.csv file into a DataFrame
print(df.head(5))
# Out:
#   Employee_ID Employee_Name               Designation  Salary
# 0     EMP0001    Employee_1  Senior Software Engineer   83278
# 1     EMP0002    Employee_2           Project Manager  122098
# 2     EMP0003    Employee_3            Data Scientist   88289
# 3     EMP0004    Employee_4  Senior Software Engineer  168696
# 4     EMP0005    Employee_5           DevOps Engineer   81395

# %%
plt.xlabel("Employee Name")#to set the label for the x-axis
plt.ylabel("Salary")#to set the label for the y-axis
plt.title("Employee Salary Distribution")#to set the title of the plot
plt.show()#to display the plot

# %%
plt.plot(df["Employee_Name"], df["Salary"])#to create a line plot with the specified x and y labels
plt.show()#to display the plot

# %%
plt.bar(employee_names, salaries)#to create a bar chart with the specified employee names and salaries
plt.xlabel("Employee Name")#to set the label for the x-axis
plt.ylabel("Salary")#to set the label for the y-axis
plt.title("Employee Salary Distribution")#to set the title of the plot
plt.show()#to display the plot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 plt.bar(employee_names, salaries)#to create a bar chart with the specified employee names and salaries
#       2 plt.xlabel("Employee Name")#to set the label for the x-axis
#       3 plt.ylabel("Salary")#to set the label for the y-axis
#
# NameError: name 'employee_names' is not defined
